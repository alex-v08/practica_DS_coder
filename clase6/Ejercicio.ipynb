# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv('/home/atuhome/Documents/CoderHouse/Datascience/cursos-python/Practica/clase6/us_presidents 2.csv')   # carga el archivo presidentes.csv

# %%
df.head(10)
# Out:
#    Unnamed: 0  S.No.           start            end               president  \
# 0           0      1  April 30, 1789  March 4, 1797       George Washington
# 1           1      2   March 4, 1797  March 4, 1801              John Adams
# 2           2      3   March 4, 1801  March 4, 1809        Thomas Jefferson
# 3           3      4   March 4, 1809  March 4, 1817           James Madison
# 4           4      5   March 4, 1817  March 4, 1825            James Monroe
# 5           5      6   March 4, 1825  March 4, 1829       John Quincy Adams
# 6           6      7   March 4, 1829  March 4, 1837          Andrew Jackson
# 7           7      8   March 4, 1837  March 4, 1841        Martin Van Buren
# 8           8      9   March 4, 1841  April 4, 1841  William Henry Harrison
# 9           9     10   April 4, 1841  March 4, 1845              John Tyler
#
#                                                prior  \
# 0  Commander-in-Chief  of the  Continental Army  ...
# ...

# %%
lista = df['start'] <= '1850-01-01'

# %%
df['start'] == lista
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# Name: start, dtype: bool
